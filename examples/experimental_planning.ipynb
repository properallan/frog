# %%
import sys
sys.path.append('/home/ppiper/github/frog')

from frog.datahandler import HDF5Handler, sliceDataAlongAxis
import numpy as np

# %%
import pandas as pd
# doe file
doe_variables = pd.read_csv('/home/ppiper/ihtc_repository/data/doe_more_design_variables/doe_more_design_variables.txt')
doe_variables
# Out:
#       ID  Thickness     CP3_y   T0in           p0in  outerTemperature
# 0      1   0.007030 -0.004963  489.0  823256.603023             359.0
# 1      2   0.005604 -0.002314  451.0  753770.670255             376.0
# 2      3   0.006003 -0.001235  507.0  476838.644912             393.0
# 3      4   0.008308 -0.007900  658.0  977509.597900             322.0
# 4      5   0.003407 -0.003504  423.0  519674.714115             291.0
# ..   ...        ...       ...    ...            ...               ...
# 145  146   0.008831 -0.007996  653.0  612997.514352             324.0
# 146  147   0.006905 -0.011722  486.0  430778.163564             296.0
# 147  148   0.007987 -0.004203  557.0  640113.474630             372.0
# 148  149   0.007307 -0.007670  456.0  930599.595474             387.0
# 149  150   0.005955 -0.002148  661.0  779572.120052             375.0
#
# [150 rows x 6 columns]

# %%
import pyvista as pv
for id in doe_variables.ID:
    solution_file = f'/home/ppiper/ihtc_repository/data/doe_more_design_variables/{id}/SU2/outputs/cht_setupSU2.vtm'
    pv.read(solution_file)

# %%
# generate dataset file
import glob

for path in glob.glob():
# Out:
# ['/home/ppiper/ihtc_repository/data/doe_more_design_variables/63',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/81',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/95',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/84',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/28',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/101',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/120',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/21',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/105',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/102',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/88',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/3',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/87',
#  '/home/ppiper/ihtc_repository/data/doe_more_design_variables/29',
# ...

# %%
hfdh = HDF5Handler(
    datapath='/home/ppiper/Dropbox/local/ihtc_nozzle/data/doe_lhs_multirun_N200/SU2_fluid_transposed.hdf5',
    datasets = ['Pressure', 'Temperature', 'Mach', 'Heat_Flux'],
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hfdh = HDF5Handler(
#       2     datapath='/home/ppiper/Dropbox/local/ihtc_nozzle/data/doe_lhs_multirun_N200/SU2_fluid_transposed.hdf5',
#       3     datasets = ['Pressure', 'Temperature', 'Mach', 'Heat_Flux'],
#       4 )
#
# File ~/github/frog/frog/datahandler/_hdf5.py:194, in HDF5Handler.__init__(self, datapath, datasets)
#     192 self.datapath : str = datapath
#     193 self.data : np.dnarray = None
# --> 194 self._load_data(datasets)
#
# File ~/github/frog/frog/datahandler/_hdf5.py:206, in HDF5Handler._load_data(self, datasets)
#     196 def _load_data(self, datasets: list = None) -> np.ndarray:
#     197     """Load the data from the HDF5 file.
#     198
#     199     Args:
#    (...)
#     203         np.ndarray: Array containing the data of all datasets.
#     204     """
# ...

# %%
hfdh.datapath
# Out:
# Failed to start the Kernel 'frenv (Python 3.11.2)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Cannot find module './351.node.js'
#
# Require stack:
#
# - /home/ppiper/.vscode-server/extensions/ms-toolsai.jupyter-2023.4.1011241018-linux-x64/out/extension.node.js
#
# - /home/ppiper/.vscode-server/bin/2ccd690cbff1569e4a83d7c43d45101f817401dc/out/vs/loader.js
#
# - /home/ppiper/.vscode-server/bin/2ccd690cbff1569e4a83d7c43d45101f817401dc/out/bootstrap-amd.js
#
# - /home/ppiper/.vscode-server/bin/2ccd690cbff1569e4a83d7c43d45101f817401dc/out/bootstrap-fork.js

# %%
import h5py

h5py.File()
